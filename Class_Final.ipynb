# %%
from Class_Final_Assignment import FinalAssignment

# %%
FinalAssignment.SubFields()
# Out:
# Sub-Fields in AI are:
#         Machine Learning
#         Neutral Netowrks
#         Vision
#         Robotics
#         Speech Processing
#         Natural Language processing

# %%
FinalAssignment.OddEven()
# Out:
# Enter the number 5689
# 5689 is Odd number

# %%
FinalAssignment.MarriageEligibility()
# Out:
# Your Gender: male
# Your ager: 45
# Eligible for marriage

# %%
FinalAssignment.triangle()
# Out:
# Height: 45
# Breadth: 56
# Area Formula : (height*breadth)/2
# Area of Traingle:  1260.0
# Height1: 78
# Height2: 45
# Breadth: 56
# Perimeter formula : height1+height2+breadth
# perimeter of triangle :  179
