# %%
num1=int(input("Num1="))
num2=int(input("Num2="))
print("Add=",num1+num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
bmi=int(input("Enter the BMI Index:"))
if (bmi<18):
    print("Underweight")
elif (bmi<25):
    print("Healthy Weight")
elif (bmi<30):
    print("Overweight")
else:
    print("Very Overweight")
# Out:
# Enter the BMI Index: 34
# Very Overweight
