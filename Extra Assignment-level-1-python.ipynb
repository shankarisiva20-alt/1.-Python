# %%
print("Hope AI")
# Out:
# Hope AI

# %%
print(input("Enter your Institute name?"))
# Out:
# Enter your Institute name? HOPE AI
# HOPE AI

# %%
print(input("Enter your name"))
print(int(input("Enter your age")))
print(input("Enter your School name"))
print(input("Enter your Degree"))
# Out:
# Enter your name Shiva
# Shiva
# Enter your age 37
# 37
# Enter your School name IHM
# IHM
# Enter your Degree BSc
# BSc

# %%
num1=int(input("a="))
num2=int(input("b="))
print("add=", num1+num2)
# Out:
# a= 43
# b= 34
# add= 77

# %%
num1=int(input("a="))
num2=int(input("b="))
print("sub=", num1-num2)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
num1=int(input("a="))
num2=int(input("b="))
print("mul=", num1*num2)
# Out:
# a= 63
# b= 97
# mul= 6111

# %%
num1=int(input("a="))
num2=int(input("b="))
print("Float_Div=", num1/num2)
# Out:
# a= 76
# b= 31
# Float_Div= 2.4516129032258065

# %%
num1=int(input("a="))
num2=int(input("b="))
print("Floor_Div=", num1//num2)
# Out:
# a= 76
# b= 31
# Floor_Div= 2

# %%
num1=int(input("a="))
num2=int(input("b="))
print("modulo=", num1%num2)
# Out:
# a= 76
# b= 31
# modulo= 14

# %%
num1=int(input("a="))
num2=int(input("b="))
print("Power=", num1**num2)
# Out:
# a= 4
# b= 4
# Power= 256
